# %%
# !pip install tensorflow
# Out:
# ^C
# ...
#    ---------------------------------------- 0.0/351.2 MB ? eta -:--:--
#    ---------------------------------------- 1.8/351.2 MB 14.7 MB/s eta 0:00:24
#    ---------------------------------------- 3.9/351.2 MB 15.6 MB/s eta 0:00:23
#     --------------------------------------- 5.2/351.2 MB 9.7 MB/s eta 0:00:36
#     --------------------------------------- 6.3/351.2 MB 8.3 MB/s eta 0:00:42
#     --------------------------------------- 7.3/351.2 MB 7.6 MB/s eta 0:00:46
#     --------------------------------------- 8.7/351.2 MB 7.3 MB/s eta 0:00:47
#     --------------------------------------- 8.7/351.2 MB 7.3 MB/s eta 0:00:47
#     --------------------------------------- 8.7/351.2 MB 7.3 MB/s eta 0:00:47
#     --------------------------------------- 8.7/351.2 MB 7.3 MB/s eta 0:00:47
#    - -------------------------------------- 9.2/351.2 MB 4.4 MB/s eta 0:01:18
#    - -------------------------------------- 10.2/351.2 MB 4.4 MB/s eta 0:01:17
# ...

# %%
import tensorflow as tf

# %%
tf
# Out:
# <module 'tensorflow' from 'C:\\Users\\Atharva Nilesh Rane\\anaconda3\\Lib\\site-packages\\tensorflow\\__init__.py'>
