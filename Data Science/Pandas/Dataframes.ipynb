# %%
import pandas as pd

# %%
data={
    "name" :["atharva","amogh","shllok"],
    "marks" :[12,13,14]
}
d = pd.DataFrame(data)
d
# Out:
#       name  marks
# 0  atharva     12
# 1    amogh     13
# 2   shllok     14

# %%
temp = [["harry",34] ,["shllok",89],["amogh",45]]
temp
# Out:
# [['harry', 34], ['shllok', 89], ['amogh', 45]]

# %%
b = pd.DataFrame(temp,columns=["name","marks"])

# %%
b
# Out:
#      name  marks
# 0   harry     34
# 1  shllok     89
# 2   amogh     45

# %%
df = pd.read_excel("data.xlsx")
df
# Out:
#      name School  marks
# 0   Arnav    PTV     45
# 1   Aarav   Mbbs     56
# 2  Chetan    MNB     58
# 3  Nilesh    NBH     89
# 4  Shllok    JIK     23

# %%
df = pd.read_excel("data.xlsx")

# %%
df
# Out:
#      name School  marks
# 0   Arnav    PTV     45
# 1   Aarav   Mbbs     56
# 2  Chetan    MNB     58
# 3  Nilesh    NBH     89
# 4  Shllok    JIK     23

# %%
s = pd.read_csv("data.csv")

# %%
s
# Out:
#      name School  marks
# 0   Arnav    PTV     45
# 1   Aarav   Mbbs     56
# 2  Chetan    MNB     58
# 3  Nilesh    NBH     89
# 4  Shllok    JIK     23
